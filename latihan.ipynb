# %% [markdown]
# # GRADED CHALLENGE

# %% [markdown]
# - Nama : Nicholas Haryadi
# - Batch : HCK-005
#
# Pada notebook ini akan dilakukan analisis terhadap ...

# %% [markdown]
# ## IMPORT LIBRARY

# %%
import pandas as pd

# %% [markdown]
# ## DATA LOADING AND OVERVIEW

# %%
df = pd.read_csv(r'C:\Users\HP\Desktop\PandasNBA\dataset\nbaallelo.csv.csv')

# %%
df.head(2)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...   40.29483     NYK    Knicks       68
# 1            0     NYK   Knicks  ...   41.70517     TRH   Huskies       66
#
#   opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# 0    1300.0  1306.7233              H            L  0.640065   NaN
# 1    1300.0  1293.2767              A            W  0.359935   NaN
#
# [2 rows x 23 columns]

# %%
df.tail(2)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# 126312   Warriors      105  1813.6349  1822.2881              H            L
# 126313  Cavaliers       97  1700.7391  1692.0859              A            W
#
#         forecast notes
# 126312   0.48145   NaN
# 126313   0.51855   NaN
#
# [2 rows x 23 columns]

# %%
df.sample(5)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 53775       26888  198511050UTA   NBA        1     1986   11/5/1985
# 66550       33276  199105030IND   NBA        0     1991    5/3/1991
# 26970       13486  197211180CHI   NBA        0     1973  11/18/1972
# 114599      57300  201012300DAL   NBA        0     2011  12/30/2010
# 113306      56654  201004030NJN   NBA        0     2010    4/3/2010
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 53775            6            0     GSW   Warriors  ...  26.751680     UTA
# 66550           86            1     IND     Pacers  ...  44.427731     BOS
# 26970           16            0     CHI      Bulls  ...  52.619053     BAL
# 114599          31            0     DAL  Mavericks  ...  54.905243     SAS
# 113306          76            0     NJN       Nets  ...  21.996107     NOH
#
#         opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df.head(5)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.info
# Out:
# <bound method DataFrame.info of         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
df.describe().T
# Out:
#                 count          mean           std          min           25%  \
# gameorder    126314.0  31579.000000  18231.927643     1.000000  15790.000000
# _iscopy      126314.0      0.500000      0.500002     0.000000      0.000000
# year_id      126314.0   1988.200374     17.582309  1947.000000   1975.000000
# seasongame   126314.0     43.533733     25.375178     1.000000     22.000000
# is_playoffs  126314.0      0.063857      0.244499     0.000000      0.000000
# pts          126314.0    102.729982     14.814845     0.000000     93.000000
# elo_i        126314.0   1495.236055    112.139945  1091.644500   1417.237975
# elo_n        126314.0   1495.236055    112.461687  1085.774400   1416.994900
# win_equiv    126314.0     41.707889     10.627332    10.152501     34.103035
# opp_pts      126314.0    102.729982     14.814845     0.000000     93.000000
# opp_elo_i    126314.0   1495.236055    112.139945  1091.644500   1417.237975
# ...

# %%
df[['team_id', 'fran_id', 'pts']]
# Out:
#        team_id    fran_id  pts
# 0          TRH    Huskies   66
# 1          NYK     Knicks   68
# 2          CHS      Stags   63
# 3          NYK     Knicks   47
# 4          DTF    Falcons   33
# ...        ...        ...  ...
# 126309     CLE  Cavaliers   82
# 126310     GSW   Warriors  104
# 126311     CLE  Cavaliers   91
# 126312     CLE  Cavaliers   97
# 126313     GSW   Warriors  105
#
# [126314 rows x 3 columns]

# %%
df['team_id'].unique() #JUMLAH UNIQUE
# Out:
# array(['TRH', 'NYK', 'CHS', 'DTF', 'WSC', 'BOS', 'PRO', 'PIT', 'STB',
#        'CLR', 'PHW', 'BLB', 'INJ', 'FTW', 'MNL', 'ROC', 'TRI', 'DNN',
#        'INO', 'SHE', 'WAT', 'AND', 'SYR', 'MLH', 'STL', 'DET', 'CIN',
#        'LAL', 'CHP', 'CHZ', 'SFW', 'BAL', 'PHI', 'CHI', 'SEA', 'OAK',
#        'ANA', 'SDR', 'KEN', 'INA', 'DNR', 'DLC', 'HSM', 'NOB', 'MNM',
#        'NJA', 'PTP', 'ATL', 'MIL', 'PHO', 'NYA', 'MMF', 'MNP', 'LAS',
#        'CAR', 'WSA', 'BUF', 'CLE', 'UTS', 'FLO', 'PTC', 'POR', 'VIR',
#        'TEX', 'MMP', 'HOU', 'GSW', 'KCO', 'MMT', 'SDA', 'CAP', 'SAA',
#        'NOJ', 'DNA', 'SSL', 'MMS', 'WSB', 'KCK', 'SDS', 'IND', 'NYN',
#        'DEN', 'SAS', 'NJN', 'SDC', 'UTA', 'DAL', 'LAC', 'SAC', 'CHH',
#        'MIA', 'MIN', 'ORL', 'VAN', 'TOR', 'WAS', 'MEM', 'NOH', 'CHA',
#        'NOK', 'OKC', 'BRK', 'NOP', 'CHO'], dtype=object)

# %%
df['team_id'].nunique() #JUMLAH TABEL YG UNIQUE
# Out:
# 104

# %%
df['team_id'].value_counts().head() #head buat paling 5 teratas
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# Name: team_id, dtype: int64

# %%
df['fran_id'].value_counts().head()
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Name: fran_id, dtype: int64

# %% [markdown]
# Terdapat ketidak konsistensian pada data dimana kolom fran_id menunjukkan

# %%
# .loc & .iloc
# loc = label terlampir ( seng diatas kaya year_id,dll )
# iloc = index penomoran
df.loc[df['fran_id'] == 'Lakers', 'team_id'].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
5078 + 946
# Out:
# 6024

# %% [markdown]
# Diketahui bahwa Lakers memiliki 2 kode yaitu LAL dan MNL sehingga setelah dari 2 kode itu dijumlahkan maka Lakers memiliki jumlah point 6024.

# %%
df.loc[df['fran_id'] == 'Lakers', 'pts'].mean()
# Out:
# 105.81739707835325

# %%
df.iloc[:, 10]
# Out:
# 0          66
# 1          68
# 2          63
# 3          47
# 4          33
#          ...
# 126309     82
# 126310    104
# 126311     91
# 126312     97
# 126313    105
# Name: pts, Length: 126314, dtype: int64

# %% [markdown]
# ## QUERY

# %%
df[df['fran_id'] == 'Lakers'][['fran_id', 'team_id']]
# Out:
#        fran_id team_id
# 1136    Lakers     MNL
# 1152    Lakers     MNL
# 1159    Lakers     MNL
# 1170    Lakers     MNL
# 1183    Lakers     MNL
# ...        ...     ...
# 126016  Lakers     LAL
# 126052  Lakers     LAL
# 126086  Lakers     LAL
# 126115  Lakers     LAL
# 126137  Lakers     LAL
#
# [6024 rows x 2 columns]

# %%
# fran_id = Warriors
# year_id = diatas 2010
# points > 100
# game location away
df [(df['fran_id'] == 'Warriors') &
   (df['year_id']> 2010) &
   (df['pts']>100) &
   (df['game_location'] == 'A')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113853      56927  201011080TOR   NBA        1     2011   11/8/2010
# 113874      56938  201011100NYK   NBA        1     2011  11/10/2010
# 114076      57039  201011240HOU   NBA        1     2011  11/24/2010
# 114106      57054  201011260MEM   NBA        1     2011  11/26/2010
# 114127      57064  201011270MIN   NBA        1     2011  11/27/2010
# ...           ...           ...   ...      ...      ...         ...
# 126280      63141  201505150MEM   NBA        1     2015   5/15/2015
# 126292      63147  201505230HOU   NBA        1     2015   5/23/2015
# 126296      63149  201505250HOU   NBA        1     2015   5/25/2015
# 126308      63155  201506110CLE   NBA        1     2015   6/11/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# ...

# %%
# fran_id = Warriors
# year_id = diatas 2010
# points > 100
# game location away
df.query('fran_id == "Warriors" \
         & year_id > 2010 \
         & pts > 100 \
         & game_location == "A"')
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113853      56927  201011080TOR   NBA        1     2011   11/8/2010
# 113874      56938  201011100NYK   NBA        1     2011  11/10/2010
# 114076      57039  201011240HOU   NBA        1     2011  11/24/2010
# 114106      57054  201011260MEM   NBA        1     2011  11/26/2010
# 114127      57064  201011270MIN   NBA        1     2011  11/27/2010
# ...           ...           ...   ...      ...      ...         ...
# 126280      63141  201505150MEM   NBA        1     2015   5/15/2015
# 126292      63147  201505230HOU   NBA        1     2015   5/23/2015
# 126296      63149  201505250HOU   NBA        1     2015   5/25/2015
# 126308      63155  201506110CLE   NBA        1     2015   6/11/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id   fran_id  pts      elo_i      elo_n  \
# ...

# %% [markdown]
# ## GROUPBY & AGGREGATION

# %%
df.groupby('game_location')['pts'].mean()
# Out:
# game_location
# A    100.856616
# H    104.602395
# N    104.315789
# Name: pts, dtype: float64

# %%
grup = df.groupby('game_location')

# %%
grup.get_group('A')['pts'].mean()
# Out:
# 100.85661566726853

# %%
grup.get_group('H')['pts'].mean()
# Out:
# 104.60239475434761

# %%
grup.get_group('N')['pts'].mean()
# Out:
# 104.3157894736842

# %%
df.groupby('game_location').agg({'pts':'mean','year_id':'max'})
# Out:
#                       pts  year_id
# game_location
# A              100.856616     2015
# H              104.602395     2015
# N              104.315789     2015

# %%
df.groupby(['game_location', 'game_result'])['pts'].mean()
# Out:
# game_location  game_result
# A              L               97.221600
#                W              106.851424
# H              L               97.558763
#                W              108.873375
# N              L               98.473684
#                W              110.157895
# Name: pts, dtype: float64

# %%
#hitung rata rata point BOSTON vs CHICAGO di tiap tahun dari 2010-2015
df[(df['fran_id'] == 'Celtics') &
    (df['opp_fran'] == 'Bulls') &
    (df['year_id'] >= 2010) &
    (df['year_id'] <= 2015)].groupby('year_id')['pts'].mean()
# Out:
# year_id
# 2010    100.00
# 2011     93.50
# 2012     85.00
# 2013     90.00
# 2014     88.00
# 2015    103.75
# Name: pts, dtype: float64

# %% [markdown]
# ## DATA MANIPULATION
# - Rename Column
# - Drop Column
# - Create new Column

# %%
#rename columns
df.rename(columns={'game_location':'loc',
                    'game_result':'result'}, inplace=True)

# %%
#drop columns
df.drop(columns=['elo_i','elo_n','notes'], inplace=True)

# %%
#drop index (baris)
df.drop(index=[1,3,5,7],axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 2
#       1 #drop index (baris)
# ----> 2 df.drop(index=[1,3,5,7],axis=0, inplace=True)
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\HP\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df['selisih'] = df['pts']- df['opp_pts']

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# 6               4  194611020PRO   NBA        1     1947  11/2/1946
# 8               5  194611020STB   NBA        1     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...
